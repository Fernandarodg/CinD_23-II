# %% [markdown]
# <a href="https://colab.research.google.com/github/Fernandarodg/CinD_23-II/blob/main/05_Dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1.Libraries**

# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %% [markdown]
# # **2. Import File**
#
# * Upload the file to Colab
# * Right click on the file and copy the path

# %%
# read the file

## Save the path
p = '/content/BASE DE EMPLEO Oficial.xlsx'

# Read ans create the dataframe
d = pd.read_excel(p)
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1120 entries, 0 to 1119
# Data columns (total 13 columns):
#  #   Column                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                 --------------  -----
#  0   Year                                                                                   1120 non-null   int64
#  1   Country                                                                                1120 non-null   object
#  2   GDP per capita (current US$)                                                           1120 non-null   object
#  3   Total population                                                                       1120 non-null   int64
#  4   Percentage of wage workers, total (modeled ILO estimate)                               1120 non-null   float64
# ...

# %%
# Explore
d.head()
# Out:
#    Year      Country GDP per capita (current US$)  Total population  \
# 0  2014  Afghanistan                   628.146804          32716210
# 1  2014       Angola                  5059.080441          27128337
# 2  2014    Argentina                 12334.798245          42669500
# 3  2014      Armenia                  4017.229913           2889930
# 4  2014   Azerbaijan                   7890.83525           9535079
#
#    Percentage of wage workers, total (modeled ILO estimate)  \
# 0                                           13.98273
# 1                                           36.66563
# 2                                           76.34650
# 3                                           55.86226
# 4                                           33.25963
#
#    Own-account workers, total (% of total employment) (modeled ILO estimate))  \
# 0                                           86.01729
# 1                                           63.33441
# ...

# %%
# Explore
d.tail()
# Out:
#       Year                      Country GDP per capita (current US$)  \
# 1115  2020          Low & middle income                  4729.766987
# 1116  2020                North America                 61461.121126
# 1117  2020                 OECD members                 38341.320759
# 1118  2020  Pacific island small states                  3713.506943
# 1119  2020           Sub-Saharan Africa                    1488.7955
#
#       Total population  \
# 1115        6550746999
# 1116         369582571
# 1117        1370222158
# 1118           2566819
# 1119        1151302081
#
#       Percentage of wage workers, total (modeled ILO estimate)  \
# 1115                                          45.127069
# 1116                                          92.692745
# 1117                                          83.942631
# 1118                                          49.687011
# 1119                                          23.220315
#
# ...

# %% [markdown]
# # **3.Cleaning**

# %% [markdown]
# ## Column names

# %%
# Year to year
d.rename(columns = {'Year':'year'}, inplace = True)

# Total population to pop
d.rename(columns = {'Total population':'pop'}, inplace = True)

# GPD per capita to GDP
d.rename(columns = {'GDP per capita (current US$)':'GDP'}, inplace = True)

# Percentage of wage workers, total (modeled ILO estimate) to wage workers
d.rename(columns = {'Percentage of wage workers, total (modeled ILO estimate)':'wage workers'}, inplace = True)

# Own-account workers, total (% of total employment) (modeled ILO estimate)) to Own-account workers
d.rename(columns = {'Own-account workers, total (% of total employment) (modeled ILO estimate))':'Own-account workers'}, inplace = True)

# Vulnerable employment, total (% of total employment) (modeled ILO estimate) to  Vulnerable employment
d.rename(columns = {'Vulnerable employment, total (% of total employment) (modeled ILO estimate)':'Vulnerable employment'}, inplace = True)

d.head()
# Out:
#    year      Country           GDP       pop  wage workers  \
# 0  2014  Afghanistan    628.146804  32716210      13.98273
# 1  2014       Angola   5059.080441  27128337      36.66563
# 2  2014    Argentina  12334.798245  42669500      76.34650
# 3  2014      Armenia   4017.229913   2889930      55.86226
# 4  2014   Azerbaijan    7890.83525   9535079      33.25963
#
#    Own-account workers  Vulnerable employment  \
# 0             86.01729              84.494340
# 1             63.33441              58.544130
# 2             23.65348              20.177971
# 3             44.13774              42.723298
# 4             66.74039              56.673540
#
#    Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# 0                                              7.910
# 1                                              9.580
# 2                                              7.270
# 3                                             11.862
# ...

# %% [markdown]
# # Delete Columns

# %%
# d = d.drop(columns = ['Laborforce,total'])
# d.info()

# %% [markdown]
# # **4. Indexing**

# %%
# Duplicate the dataframe
d2 = d

# %%
# Duplicate year as string / how to create a column
d2['year_str'] = d2['year'].astype(str)
d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1120 entries, 0 to 1119
# Data columns (total 14 columns):
#  #   Column                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                 --------------  -----
#  0   year                                                                                   1120 non-null   int64
#  1   Country                                                                                1120 non-null   object
#  2   GDP                                                                                    1120 non-null   object
#  3   pop                                                                                    1120 non-null   int64
#  4   wage workers                                                                           1120 non-null   float64
# ...

# %%
# Indexing
idx = pd.MultiIndex.from_product([d2['Country'].unique(),range(d2.year.min(),d2.year.max()+1)],
                                 names = ['Country', 'year'])

## Attach the index
d2 = d2.set_index(['Country', 'year'])

d2.head()
# Out:
#                            GDP       pop  wage workers  Own-account workers  \
# Country     year
# Afghanistan 2014    628.146804  32716210      13.98273             86.01729
# Angola      2014   5059.080441  27128337      36.66563             63.33441
# Argentina   2014  12334.798245  42669500      76.34650             23.65348
# Armenia     2014   4017.229913   2889930      55.86226             44.13774
# Azerbaijan  2014    7890.83525   9535079      33.25963             66.74039
#
#                   Vulnerable employment  \
# Country     year
# Afghanistan 2014              84.494340
# Angola      2014              58.544130
# Argentina   2014              20.177971
# Armenia     2014              42.723298
# Azerbaijan  2014              56.673540
#
#                   Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# Country     year
# Afghanistan 2014                                              7.910
# ...

# %%
d2['Country'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
range(d2.year.min(),d2.year.max()+1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-106-8e5ddacac492> in <cell line: 1>()
# ----> 1 range(d2.year.min(),d2.year.max()+1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'year'

# %% [markdown]
# ##**5 Delete NaN**

# %%
# Display if there ara NaN
d2.isna()
# Out:
#                                     GDP    pop  wage workers  \
# Country                     year
# Afghanistan                 2014  False  False         False
# Angola                      2014  False  False         False
# Argentina                   2014  False  False         False
# Armenia                     2014  False  False         False
# Azerbaijan                  2014  False  False         False
# ...                                 ...    ...           ...
# Low & middle income         2020  False  False         False
# North America               2020  False  False         False
# OECD members                2020  False  False         False
# Pacific island small states 2020  False  False         False
# Sub-Saharan Africa          2020  False  False         False
#
#                                   Own-account workers  Vulnerable employment  \
# Country                     year
# Afghanistan                 2014                False                  False
# ...

# %%
# Delete NaN
d2 = d2.dropna()
d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1120 entries, ('Afghanistan', 2014) to ('Sub-Saharan Africa', 2020)
# Data columns (total 12 columns):
#  #   Column                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                 --------------  -----
#  0   GDP                                                                                    1120 non-null   object
#  1   pop                                                                                    1120 non-null   int64
#  2   wage workers                                                                           1120 non-null   float64
#  3   Own-account workers                                                                    1120 non-null   float64
#  4   Vulnerable employment                                                                  1120 non-null   float64
# ...

# %%
# By the flies
d2 = d2.replace('..',np.NaN)
d2.head()
# Out:
#                            GDP       pop  wage workers  Own-account workers  \
# Country     year
# Afghanistan 2014    628.146804  32716210      13.98273             86.01729
# Angola      2014   5059.080441  27128337      36.66563             63.33441
# Argentina   2014  12334.798245  42669500      76.34650             23.65348
# Armenia     2014   4017.229913   2889930      55.86226             44.13774
# Azerbaijan  2014   7890.835250   9535079      33.25963             66.74039
#
#                   Vulnerable employment  \
# Country     year
# Afghanistan 2014              84.494340
# Angola      2014              58.544130
# Argentina   2014              20.177971
# Armenia     2014              42.723298
# Azerbaijan  2014              56.673540
#
#                   Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# Country     year
# Afghanistan 2014                                              7.910
# ...

# %% [markdown]
# # **6. Descriptive Statistics**

# %%
# Basic
d2 [['pop','GDP','wage workers']].describe().applymap(lambda x: '{:.1f}'.format(x))
# Out:
#                 pop       GDP wage workers
# count        1120.0    1114.0       1120.0
# mean    103327209.3   14846.2         60.4
# std     535066009.9   20328.8         25.9
# min        104632.0     216.8          4.7
# 25%       2925502.8    2056.3         40.9
# 50%      10134167.5    5898.8         66.5
# 75%      36388713.2   18188.2         84.2
# max    6550746999.0  123678.7         99.6

# %% [markdown]
# Story

# %%
# By indexd2
d2[['pop']].groupby('Country').describe().applymap(lambda x:'{:.1f}'.format(x))
# Out:
#                         pop                                        \
#                       count         mean         std          min
# Country
# Afghanistan             7.0   35739692.4   2227844.8   32716210.0
# Angola                  7.0   30239291.3   2273939.8   27128337.0
# Arab World              7.0  423772774.9  18619727.5  397922915.0
# Argentina               7.0   44035231.7    975194.0   42669500.0
# Armenia                 7.0    2849864.3     30773.4    2805608.0
# ...                     ...          ...         ...          ...
# Virgin Islands (U.S.)   7.0     107193.0       574.9     106290.0
# West Bank and Gaza      7.0    4474720.7    225774.5    4173398.0
# Yemen, Rep.             7.0   30028498.6   1633242.3   27753304.0
# Zambia                  7.0   17313703.3   1149836.7   15737793.0
# Zimbabwe                7.0   14755850.4    651226.5   13855753.0
#
#
#                                25%          50%          75%          max
# Country
# ...

# %% [markdown]
# Historia por indice:
#
# The population index can be used to compare the population of different countries, as well as to identify trends in population growth or decline. For example, the index shows that China has the largest population in the world, with a population of over 1.4 billion people. The index also shows that the population of the world is growing rapidly, with the mean population growth rate being about 2% per year.
#
# The population index is a valuable tool for policymakers and economists around the world. They can use it to make informed decisions about how to manage population growth and ensure that everyone has access to the resources they need.

# %% [markdown]
# ## **7. Basic Graph**

# %%
# Scatter matrix
fig1 = px.scatter_matrix(d2, dimensions = ['GDP','pop', 'wage workers',], color = 'year_str')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Scatter matrix
fig1 = px.scatter_matrix(d2, dimensions = ['GDP','pop', 'wage workers',], color = 'year_str')
fig1.update_traces(diagonal_visible = False)
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Scatter matrix
fig1 = px.scatter_matrix(d2, dimensions = ['GDP','pop', 'wage workers',], color = 'year_str')
fig1.update_traces(diagonal_visible = False)
fig1.update_traces(showupperhalf = False)
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# escribir analisis
