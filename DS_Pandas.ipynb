# %% [markdown]
# <a href="https://colab.research.google.com/github/Fernandarodg/CinD_23-II/blob/main/DS_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Data Structures - Pandas**

# %% [markdown]
# ## Two types
# series  - una dimensión
# Dataframes - more dimensions
#
# - corte trasversal / cross-section, Países, indice de felicidad
# - Serie de tiempo / Time-series: fechas, minutos, segundos, decadas
# - Panel / Panel de datos muchas fotos, en varias series de tiempo (base de datos de excel)
#   Dataframes es panel

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 2. Pandas Series

# %% [markdown]
# 2.1 Series Creation

# %%
# Empty series
s_empty = pd.Series()
print(s_empty)
# Out:
# Series([], dtype: float64)
# <ipython-input-2-6419cb35d0c9>:2: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s_empty = pd.Series()

# %%
# A number series
s_int = pd.Series([1,2,3,4,5])
print(s_int)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# Using random numbers
s_rand = pd.Series(np.random.rand(8))
print(s_rand)
# Out:
# 0    0.840624
# 1    0.413930
# 2    0.837900
# 3    0.331792
# 4    0.405791
# 5    0.660378
# 6    0.241987
# 7    0.852590
# dtype: float64

# %%
# ???
tmp = pd.Series([1, 'b'])
print(tmp)
# Out:
# 0    1
# 1    b
# dtype: object

# %% [markdown]
# # 2.2 Indexing

# %%
# Inditex of s_rand
s_rand.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
# Redefine index
index = ['i', 'ii', 'iii', 'iv', 'v', 'vi', 'vii', 'viii']
s_rand2 = pd.Series(np.random.rand(8), index = index)
print(s_rand2)
# Out:
# i       0.175389
# ii      0.350179
# iii     0.733373
# iv      0.945438
# v       0.926106
# vi      0.279548
# vii     0.707830
# viii    0.982876
# dtype: float64

# %% [markdown]
# 2.3 Sciling

# %%
# First element
s_rand2[['i', 'vii']]
# Out:
# i      0.175389
# vii    0.707830
# dtype: float64

# %%
#Edit elements
s_rand['v'] = 100
print(s_rand2)
# Out:
# i       0.175389
# ii      0.350179
# iii     0.733373
# iv      0.945438
# v       0.926106
# vi      0.279548
# vii     0.707830
# viii    0.982876
# dtype: float64

# %%
# Operations
s_rand2 / 5
# Out:
# i       0.035078
# ii      0.070036
# iii     0.146675
# iv      0.189088
# v       0.185221
# vi      0.055910
# vii     0.141566
# viii    0.196575
# dtype: float64

# %%
# special
np.exp(s_rand2)
np.log(s_rand2)
# Out:
# i      -1.740750
# ii     -1.049311
# iii    -0.310101
# iv     -0.056106
# v      -0.076767
# vi     -1.274580
# vii    -0.345552
# viii   -0.017272
# dtype: float64

# %% [markdown]
# ## 3.**Pandas Time-series**

# %% [markdown]
# ## 3.1. Create a time index

# %%
#Example
pd.date_range(start = '20/09/2023', end = '31/12/2023')
# Out:
# <ipython-input-12-43e02fff3034>:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   pd.date_range(start = '20/09/2023', end = '31/12/2023')
# DatetimeIndex(['2023-09-20', '2023-09-21', '2023-09-22', '2023-09-23',
#                '2023-09-24', '2023-09-25', '2023-09-26', '2023-09-27',
#                '2023-09-28', '2023-09-29',
#                ...
#                '2023-12-22', '2023-12-23', '2023-12-24', '2023-12-25',
#                '2023-12-26', '2023-12-27', '2023-12-28', '2023-12-29',
#                '2023-12-30', '2023-12-31'],
#               dtype='datetime64[ns]', length=103, freq='D')

# %%
pd.date_range(start = '20/09/2023', periods = 35)
# Out:
# <ipython-input-13-40212d81bdad>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   pd.date_range(start = '20/09/2023', periods = 35)
# DatetimeIndex(['2023-09-20', '2023-09-21', '2023-09-22', '2023-09-23',
#                '2023-09-24', '2023-09-25', '2023-09-26', '2023-09-27',
#                '2023-09-28', '2023-09-29', '2023-09-30', '2023-10-01',
#                '2023-10-02', '2023-10-03', '2023-10-04', '2023-10-05',
#                '2023-10-06', '2023-10-07', '2023-10-08', '2023-10-09',
#                '2023-10-10', '2023-10-11', '2023-10-12', '2023-10-13',
#                '2023-10-14', '2023-10-15', '2023-10-16', '2023-10-17',
#                '2023-10-18', '2023-10-19', '2023-10-20', '2023-10-21',
#                '2023-10-22', '2023-10-23', '2023-10-24'],
#               dtype='datetime64[ns]', freq='D')

# %%
#Example 3
pd.date_range(start = '20/09/2023', periods =35, freq = 'MS')
# Out:
# <ipython-input-14-422b016c301b>:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   pd.date_range(start = '20/09/2023', periods =35, freq = 'MS')
# DatetimeIndex(['2023-10-01', '2023-11-01', '2023-12-01', '2024-01-01',
#                '2024-02-01', '2024-03-01', '2024-04-01', '2024-05-01',
#                '2024-06-01', '2024-07-01', '2024-08-01', '2024-09-01',
#                '2024-10-01', '2024-11-01', '2024-12-01', '2025-01-01',
#                '2025-02-01', '2025-03-01', '2025-04-01', '2025-05-01',
#                '2025-06-01', '2025-07-01', '2025-08-01', '2025-09-01',
#                '2025-10-01', '2025-11-01', '2025-12-01', '2026-01-01',
#                '2026-02-01', '2026-03-01', '2026-04-01', '2026-05-01',
#                '2026-06-01', '2026-07-01', '2026-08-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
pd.date_range(start = '20/09/2023', periods =35, freq = 'H')
# Out:
# <ipython-input-15-66095b60fb3b>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   pd.date_range(start = '20/09/2023', periods =35, freq = 'H')
# DatetimeIndex(['2023-09-20 00:00:00', '2023-09-20 01:00:00',
#                '2023-09-20 02:00:00', '2023-09-20 03:00:00',
#                '2023-09-20 04:00:00', '2023-09-20 05:00:00',
#                '2023-09-20 06:00:00', '2023-09-20 07:00:00',
#                '2023-09-20 08:00:00', '2023-09-20 09:00:00',
#                '2023-09-20 10:00:00', '2023-09-20 11:00:00',
#                '2023-09-20 12:00:00', '2023-09-20 13:00:00',
#                '2023-09-20 14:00:00', '2023-09-20 15:00:00',
#                '2023-09-20 16:00:00', '2023-09-20 17:00:00',
#                '2023-09-20 18:00:00', '2023-09-20 19:00:00',
#                '2023-09-20 20:00:00', '2023-09-20 21:00:00',
#                '2023-09-20 22:00:00', '2023-09-20 23:00:00',
#                '2023-09-21 00:00:00', '2023-09-21 01:00:00',
#                '2023-09-21 02:00:00', '2023-09-21 03:00:00',
#                '2023-09-21 04:00:00', '2023-09-21 05:00:00',
#                '2023-09-21 06:00:00', '2023-09-21 07:00:00',
#                '2023-09-21 08:00:00', '2023-09-21 09:00:00',
#                '2023-09-21 10:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
#Trimestral
pd.date_range(start = '20/10/2023', periods =35, freq = 'Q')
# Out:
# <ipython-input-16-f73dab04c6b6>:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   pd.date_range(start = '20/10/2023', periods =35, freq = 'Q')
# DatetimeIndex(['2023-12-31', '2024-03-31', '2024-06-30', '2024-09-30',
#                '2024-12-31', '2025-03-31', '2025-06-30', '2025-09-30',
#                '2025-12-31', '2026-03-31', '2026-06-30', '2026-09-30',
#                '2026-12-31', '2027-03-31', '2027-06-30', '2027-09-30',
#                '2027-12-31', '2028-03-31', '2028-06-30', '2028-09-30',
#                '2028-12-31', '2029-03-31', '2029-06-30', '2029-09-30',
#                '2029-12-31', '2030-03-31', '2030-06-30', '2030-09-30',
#                '2030-12-31', '2031-03-31', '2031-06-30', '2031-09-30',
#                '2031-12-31', '2032-03-31', '2032-06-30'],
#               dtype='datetime64[ns]', freq='Q-DEC')

# %% [markdown]
# ## 3.2 Create a time-series

# %%
#time series 1

## Create the time index
my_dates = pd.date_range(start = '01/01/2023', periods = 12, freq = 'M')

## Create the data
data = pd.Series(np.random.rand(12), index = my_dates)
print(data)
# Out:
# 2023-01-31    0.278765
# 2023-02-28    0.496056
# 2023-03-31    0.810703
# 2023-04-30    0.803001
# 2023-05-31    0.563320
# 2023-06-30    0.680013
# 2023-07-31    0.504642
# 2023-08-31    0.548408
# 2023-09-30    0.140615
# 2023-10-31    0.614165
# 2023-11-30    0.309481
# 2023-12-31    0.069816
# Freq: M, dtype: float64

# %%
data['2023-06-30']
# Out:
# 0.6800131478997417

# %% [markdown]
# # **4. Practical case - Simulation**

# %% [markdown]
# ## 4.1 Create the simulation

# %%
# Create dates

## Daily dates
hoy   = pd.to_datetime('today').strftime('%d-%m-%Y')
T     = 1500
dates = pd.date_range(end = hoy,  periods = T, freq = 'D')
# Out:
# <ipython-input-19-965921e69c09>:6: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   dates = pd.date_range(end = hoy,  periods = T, freq = 'D')

# %%
# Create a series of returns  N ~ (mu, sigma)

mu    = 0.001
sigma = 0.01

## Create T iterarions
r = np.random.normal(mu, sigma, size = T)

# %%
# Create a serie of a financial asset price

## Create the array
S    = np.empty(T)
S[0] = 100    # initial price

## fill the rest of the array
for i in range(1, T):
  S[i] = S[i-1]*np.exp(r[i])

# %%
# Bind the dates with prices
S = pd.Series(S, index = dates)

# %%
# Basic exploration
S.head()
# Out:
# 2019-08-20    100.000000
# 2019-08-21    101.868222
# 2019-08-22    100.903400
# 2019-08-23    102.512391
# 2019-08-24    101.272291
# Freq: D, dtype: float64

# %%
S.tail()
# Out:
# 2023-09-23    314.807286
# 2023-09-24    316.721703
# 2023-09-25    320.763362
# 2023-09-26    319.424367
# 2023-09-27    323.641192
# Freq: D, dtype: float64

# %% [markdown]
# **My first visualization**

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(S)
plt.show()

# %%
import plotly.express as px

# %%
fig = px.line(S, title = 'Financial Asset')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cba12d6c-ee97-4416-bad8-e7c52dc64c1a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cba12d6c-ee97-4416-bad8-e7c52dc64c1a")) {                    Plotly.newPlot(                        "cba12d6c-ee97-4416-bad8-e7c52dc64c1a",                        [{"hovertemplate":"variable=0\u003cbr\u003eindex=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"0","showlegend":true,"x":["2019-08-20T00:00:00","2019-08-21T00:00:00","2019-08-22T00:00:00","2019-08-23T00:00:00","2019-08-24T00:00:00","2019-08-25T00:00:00","2019-08-26T00:00:00","2019-08-27T00:00:00","2019-08-28T00:00:00","2019-08-29T00:00:00","2019-08-30T00:00:00","2019-08-31T00:00:00","2019-09-01T00:00:00","2019-09-02T00:00:00","2019-09-03T00:00:00","2019-09-04T00:00:00","2019-09-05T00:00:00","2019-09-06T00:00:00","2019-09-07T00:00:00","2019-09-08T00:00:00","2019-09-09T00:00:00","2019-09-10T00:00:00","2019-09-11T00:00:00","2019-09-12T00:00:00","2019-09-13T00:00:00","2019-09-14T00:00:00","2019-09-15T00:00:00","2019-09-16T00:00:00","2019-09-17T00:00:00","2019-09-18T00:00:00","2019-09-19T00:00:00","2019-09-20T00:00:00","2019-09-21T00:00:00","2019-09-22T00:00:00","2019-09-23T00:00:00","2019-09-24T00:00:00","2019-09-25T00:00:00","2019-09-26T00:00:00","2019-09-27T00:00:00","2019-09-28T00:00:00","2019-09-29T00:00:00","2019-09-30T00:00:00","2019-10-01T00:00:00","2019-10-02T00:00:00","2019-10-03T00:00:00","2019-10-04T00:00:00","2019-10-05T00:00:00","2019-10-06T00:00:00","2019-10-07T00:00:00","2019-10-08T00:00:00","2019-10-09T00:00:00","2019-10-10T00:00:00","2019-10-11T00:00:00","2019-10-12T00:00:00","2019-10-13T00:00:00","2019-10-14T00:00:00","2019-10-15T00:00:00","2019-10-16T00:00:00","2019-10-17T00:00:00","2019-10-18T00:00:00","2019-10-19T00:00:00","2019-10-20T00:00:00","2019-10-21T00:00:00","2019-10-22T00:00:00","2019-10-23T00:00:00","2019-10-24T00:00:00","2019-10-25T00:00:00","2019-10-26T00:00:00","2019-10-27T00:00:00","2019-10-28T00:00:00","2019-10-29T00:00:00","2019-10-30T00:00:00","2019-10-31T00:00:00","2019-11-01T00:00:00","2019-11-02T00:00:00","2019-11-03T00:00:00","2019-11-04T00:00:00","2019-11-05T00:00:00","2019-11-06T00:00:00","2019-11-07T00:00:00","2019-11-08T00:00:00","2019-11-09T00:00:00","2019-11-10T00:00:00","2019-11-11T00:00:00","2019-11-12T00:00:00","2019-11-13T00:00:00","2019-11-14T00:00:00","2019-11-15T00:00:00","2019-11-16T00:00:00","2019-11-17T00:00:00","2019-11-18T00:00:00","2019-11-19T00:00:00","2019-11-20T00:00:00","2019-11-21T00:00:00","2019-11-22T00:00:00","2019-11-23T00:00:00","2019-11-24T00:00:00","2019-11-25T00:00:00","2019-11-26T00:00:00","2019-11-27T00:00:00","2019-11-28T00:00:00","2019-11-29T00:00:00","2019-11-30T00:00:00","2019-12-01T00:00:00","2019-12-02T00:00:00","2019-12-03T00:00:00","2019-12-04T00:00:00","2019-12-05T00:00:00","2019-12-06T00:00:00","2019-12-07T00:00:00","2019-12-08T00:00:00","2019-12-09T00:00:00","2019-12-10T00:00:00","2019-12-11T00:00:00","2019-12-12T00:00:00","2019-12-13T00:00:00","2019-12-14T00:00:00","2019-12-15T00:00:00","2019-12-16T00:00:00","2019-12-17T00:00:00","2019-12-18T00:00:00","2019-12-19T00:00:00","2019-12-20T00:00:00","2019-12-21T00:00:00","2019-12-22T00:00:00","2019-12-23T00:00:00","2019-12-24T00:00:00","2019-12-25T00:00:00","2019-12-26T00:00:00","2019-12-27T00:00:00","2019-12-28T00:00:00","2019-12-29T00:00:00","2019-12-30T00:00:00","2019-12-31T00:00:00","2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-11T ...

# %%
# Without the Legend
fig.update_layout(showlegend = False)


# Center the title
fig.update_layout(title_text = 'Financial Asset Price',
                  title_font_size = 30,
                  title_x = 0.5)

# Modify the text in the axis
fig.update_xaxes(title = 'Dates', title_font_size = 25,
                 dtick = 'M1',
                 tickformat = '%b\n%Y')
fig.update_yaxes(title = 'USD', title_font_size = 25)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3df0962a-d0ae-49a1-a336-03ca3fc12dc6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3df0962a-d0ae-49a1-a336-03ca3fc12dc6")) {                    Plotly.newPlot(                        "3df0962a-d0ae-49a1-a336-03ca3fc12dc6",                        [{"hovertemplate":"variable=0\u003cbr\u003eindex=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"0","showlegend":true,"x":["2019-08-20T00:00:00","2019-08-21T00:00:00","2019-08-22T00:00:00","2019-08-23T00:00:00","2019-08-24T00:00:00","2019-08-25T00:00:00","2019-08-26T00:00:00","2019-08-27T00:00:00","2019-08-28T00:00:00","2019-08-29T00:00:00","2019-08-30T00:00:00","2019-08-31T00:00:00","2019-09-01T00:00:00","2019-09-02T00:00:00","2019-09-03T00:00:00","2019-09-04T00:00:00","2019-09-05T00:00:00","2019-09-06T00:00:00","2019-09-07T00:00:00","2019-09-08T00:00:00","2019-09-09T00:00:00","2019-09-10T00:00:00","2019-09-11T00:00:00","2019-09-12T00:00:00","2019-09-13T00:00:00","2019-09-14T00:00:00","2019-09-15T00:00:00","2019-09-16T00:00:00","2019-09-17T00:00:00","2019-09-18T00:00:00","2019-09-19T00:00:00","2019-09-20T00:00:00","2019-09-21T00:00:00","2019-09-22T00:00:00","2019-09-23T00:00:00","2019-09-24T00:00:00","2019-09-25T00:00:00","2019-09-26T00:00:00","2019-09-27T00:00:00","2019-09-28T00:00:00","2019-09-29T00:00:00","2019-09-30T00:00:00","2019-10-01T00:00:00","2019-10-02T00:00:00","2019-10-03T00:00:00","2019-10-04T00:00:00","2019-10-05T00:00:00","2019-10-06T00:00:00","2019-10-07T00:00:00","2019-10-08T00:00:00","2019-10-09T00:00:00","2019-10-10T00:00:00","2019-10-11T00:00:00","2019-10-12T00:00:00","2019-10-13T00:00:00","2019-10-14T00:00:00","2019-10-15T00:00:00","2019-10-16T00:00:00","2019-10-17T00:00:00","2019-10-18T00:00:00","2019-10-19T00:00:00","2019-10-20T00:00:00","2019-10-21T00:00:00","2019-10-22T00:00:00","2019-10-23T00:00:00","2019-10-24T00:00:00","2019-10-25T00:00:00","2019-10-26T00:00:00","2019-10-27T00:00:00","2019-10-28T00:00:00","2019-10-29T00:00:00","2019-10-30T00:00:00","2019-10-31T00:00:00","2019-11-01T00:00:00","2019-11-02T00:00:00","2019-11-03T00:00:00","2019-11-04T00:00:00","2019-11-05T00:00:00","2019-11-06T00:00:00","2019-11-07T00:00:00","2019-11-08T00:00:00","2019-11-09T00:00:00","2019-11-10T00:00:00","2019-11-11T00:00:00","2019-11-12T00:00:00","2019-11-13T00:00:00","2019-11-14T00:00:00","2019-11-15T00:00:00","2019-11-16T00:00:00","2019-11-17T00:00:00","2019-11-18T00:00:00","2019-11-19T00:00:00","2019-11-20T00:00:00","2019-11-21T00:00:00","2019-11-22T00:00:00","2019-11-23T00:00:00","2019-11-24T00:00:00","2019-11-25T00:00:00","2019-11-26T00:00:00","2019-11-27T00:00:00","2019-11-28T00:00:00","2019-11-29T00:00:00","2019-11-30T00:00:00","2019-12-01T00:00:00","2019-12-02T00:00:00","2019-12-03T00:00:00","2019-12-04T00:00:00","2019-12-05T00:00:00","2019-12-06T00:00:00","2019-12-07T00:00:00","2019-12-08T00:00:00","2019-12-09T00:00:00","2019-12-10T00:00:00","2019-12-11T00:00:00","2019-12-12T00:00:00","2019-12-13T00:00:00","2019-12-14T00:00:00","2019-12-15T00:00:00","2019-12-16T00:00:00","2019-12-17T00:00:00","2019-12-18T00:00:00","2019-12-19T00:00:00","2019-12-20T00:00:00","2019-12-21T00:00:00","2019-12-22T00:00:00","2019-12-23T00:00:00","2019-12-24T00:00:00","2019-12-25T00:00:00","2019-12-26T00:00:00","2019-12-27T00:00:00","2019-12-28T00:00:00","2019-12-29T00:00:00","2019-12-30T00:00:00","2019-12-31T00:00:00","2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-11T ...

# %% [markdown]
# ## 4.2. Basic Statistics

# %%
# Very basic
print('Basic Statistics')
print('Number of Obs:\t', S.size)
print('Minimum:\t', round(S.min(),2))
print('Mean:   \t', round(S.mean(),2))
print('Maximum:\t', round(S.max(),2))
# Out:
# Basic Statistics
# Number of Obs:	 1500
# Minimum:	 91.82
# Mean:   	 165.76
# Maximum:	 345.6

# %% [markdown]
# **Add statistics to the graph**

# %%
# Modify the text in the axis
fig.update_xaxes(title = 'Dates', title_font_size = 25,
                 dtick = 'M1',
                 tickformat = '%b\n%Y')
fig.update_yaxes(title = 'USD', title_font_size = 25)

## Add box
fig.add_annotation(x = '2019-10-01', y = 0.9*S.max(),
                  text = '<b> Basic statistics: </b> <br>'
                          f'Obs: {S.size} <br>'
                          f'Min: {round(S.min(),2)} <br>'
                          f'Mean:{round(S.mean(),2)} <br>'
                          f'Max: {round(S.max(),2)} <br>',
                   align = 'left',
                   showarrow = False,
                   yshift = 10)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6d0275ca-e94b-4b7f-be88-edb8202bafcd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d0275ca-e94b-4b7f-be88-edb8202bafcd")) {                    Plotly.newPlot(                        "6d0275ca-e94b-4b7f-be88-edb8202bafcd",                        [{"hovertemplate":"variable=0\u003cbr\u003eindex=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"0","showlegend":true,"x":["2019-08-20T00:00:00","2019-08-21T00:00:00","2019-08-22T00:00:00","2019-08-23T00:00:00","2019-08-24T00:00:00","2019-08-25T00:00:00","2019-08-26T00:00:00","2019-08-27T00:00:00","2019-08-28T00:00:00","2019-08-29T00:00:00","2019-08-30T00:00:00","2019-08-31T00:00:00","2019-09-01T00:00:00","2019-09-02T00:00:00","2019-09-03T00:00:00","2019-09-04T00:00:00","2019-09-05T00:00:00","2019-09-06T00:00:00","2019-09-07T00:00:00","2019-09-08T00:00:00","2019-09-09T00:00:00","2019-09-10T00:00:00","2019-09-11T00:00:00","2019-09-12T00:00:00","2019-09-13T00:00:00","2019-09-14T00:00:00","2019-09-15T00:00:00","2019-09-16T00:00:00","2019-09-17T00:00:00","2019-09-18T00:00:00","2019-09-19T00:00:00","2019-09-20T00:00:00","2019-09-21T00:00:00","2019-09-22T00:00:00","2019-09-23T00:00:00","2019-09-24T00:00:00","2019-09-25T00:00:00","2019-09-26T00:00:00","2019-09-27T00:00:00","2019-09-28T00:00:00","2019-09-29T00:00:00","2019-09-30T00:00:00","2019-10-01T00:00:00","2019-10-02T00:00:00","2019-10-03T00:00:00","2019-10-04T00:00:00","2019-10-05T00:00:00","2019-10-06T00:00:00","2019-10-07T00:00:00","2019-10-08T00:00:00","2019-10-09T00:00:00","2019-10-10T00:00:00","2019-10-11T00:00:00","2019-10-12T00:00:00","2019-10-13T00:00:00","2019-10-14T00:00:00","2019-10-15T00:00:00","2019-10-16T00:00:00","2019-10-17T00:00:00","2019-10-18T00:00:00","2019-10-19T00:00:00","2019-10-20T00:00:00","2019-10-21T00:00:00","2019-10-22T00:00:00","2019-10-23T00:00:00","2019-10-24T00:00:00","2019-10-25T00:00:00","2019-10-26T00:00:00","2019-10-27T00:00:00","2019-10-28T00:00:00","2019-10-29T00:00:00","2019-10-30T00:00:00","2019-10-31T00:00:00","2019-11-01T00:00:00","2019-11-02T00:00:00","2019-11-03T00:00:00","2019-11-04T00:00:00","2019-11-05T00:00:00","2019-11-06T00:00:00","2019-11-07T00:00:00","2019-11-08T00:00:00","2019-11-09T00:00:00","2019-11-10T00:00:00","2019-11-11T00:00:00","2019-11-12T00:00:00","2019-11-13T00:00:00","2019-11-14T00:00:00","2019-11-15T00:00:00","2019-11-16T00:00:00","2019-11-17T00:00:00","2019-11-18T00:00:00","2019-11-19T00:00:00","2019-11-20T00:00:00","2019-11-21T00:00:00","2019-11-22T00:00:00","2019-11-23T00:00:00","2019-11-24T00:00:00","2019-11-25T00:00:00","2019-11-26T00:00:00","2019-11-27T00:00:00","2019-11-28T00:00:00","2019-11-29T00:00:00","2019-11-30T00:00:00","2019-12-01T00:00:00","2019-12-02T00:00:00","2019-12-03T00:00:00","2019-12-04T00:00:00","2019-12-05T00:00:00","2019-12-06T00:00:00","2019-12-07T00:00:00","2019-12-08T00:00:00","2019-12-09T00:00:00","2019-12-10T00:00:00","2019-12-11T00:00:00","2019-12-12T00:00:00","2019-12-13T00:00:00","2019-12-14T00:00:00","2019-12-15T00:00:00","2019-12-16T00:00:00","2019-12-17T00:00:00","2019-12-18T00:00:00","2019-12-19T00:00:00","2019-12-20T00:00:00","2019-12-21T00:00:00","2019-12-22T00:00:00","2019-12-23T00:00:00","2019-12-24T00:00:00","2019-12-25T00:00:00","2019-12-26T00:00:00","2019-12-27T00:00:00","2019-12-28T00:00:00","2019-12-29T00:00:00","2019-12-30T00:00:00","2019-12-31T00:00:00","2020-01-01T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-11T ...

# %% [markdown]
# ##Resampling

# %%
# Example
SM = S. resample('M').sum()
SM.head()
# Out:
# 2019-08-31    1224.442112
# 2019-09-30    3030.969214
# 2019-10-31    2967.831707
# 2019-11-30    2811.678784
# 2019-12-31    2930.609999
# Freq: M, dtype: float64

# %%
# Example 2
m_stats = S.resample('M').agg(['count','min','mean','max'])
m_stats.head()
# Out:
#             count         min        mean         max
# 2019-08-31     12  100.000000  102.036843  104.511790
# 2019-09-30     30   93.327824  101.032307  105.070272
# 2019-10-31     31   94.142878   95.736507   98.688233
# 2019-11-30     30   92.055095   93.722626   96.474322
# 2019-12-31     31   91.822710   94.535806  100.082128

# %%
fig2 = px.line(m_stats)
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="32d54142-5334-4aef-b1de-d50d95717359" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("32d54142-5334-4aef-b1de-d50d95717359")) {                    Plotly.newPlot(                        "32d54142-5334-4aef-b1de-d50d95717359",                        [{"hovertemplate":"variable=count\u003cbr\u003eindex=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"count","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"count","orientation":"v","showlegend":true,"x":["2019-08-31T00:00:00","2019-09-30T00:00:00","2019-10-31T00:00:00","2019-11-30T00:00:00","2019-12-31T00:00:00","2020-01-31T00:00:00","2020-02-29T00:00:00","2020-03-31T00:00:00","2020-04-30T00:00:00","2020-05-31T00:00:00","2020-06-30T00:00:00","2020-07-31T00:00:00","2020-08-31T00:00:00","2020-09-30T00:00:00","2020-10-31T00:00:00","2020-11-30T00:00:00","2020-12-31T00:00:00","2021-01-31T00:00:00","2021-02-28T00:00:00","2021-03-31T00:00:00","2021-04-30T00:00:00","2021-05-31T00:00:00","2021-06-30T00:00:00","2021-07-31T00:00:00","2021-08-31T00:00:00","2021-09-30T00:00:00","2021-10-31T00:00:00","2021-11-30T00:00:00","2021-12-31T00:00:00","2022-01-31T00:00:00","2022-02-28T00:00:00","2022-03-31T00:00:00","2022-04-30T00:00:00","2022-05-31T00:00:00","2022-06-30T00:00:00","2022-07-31T00:00:00","2022-08-31T00:00:00","2022-09-30T00:00:00","2022-10-31T00:00:00","2022-11-30T00:00:00","2022-12-31T00:00:00","2023-01-31T00:00:00","2023-02-28T00:00:00","2023-03-31T00:00:00","2023-04-30T00:00:00","2023-05-31T00:00:00","2023-06-30T00:00:00","2023-07-31T00:00:00","2023-08-31T00:00:00","2023-09-30T00:00:00"],"xaxis":"x","y":[12.0,30.0,31.0,30.0,31.0,31.0,29.0,31.0,30.0,31.0,30.0,31.0,31.0,30.0,31.0,30.0,31.0,31.0,28.0,31.0,30.0,31.0,30.0,31.0,31.0,30.0,31.0,30.0,31.0,31.0,28.0,31.0,30.0,31.0,30.0,31.0,31.0,30.0,31.0,30.0,31.0,31.0,28.0,31.0,30.0,31.0,30.0,31.0,31.0,27.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=min\u003cbr\u003eindex=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"min","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"min","orientation":"v","showlegend":true,"x":["2019-08-31T00:00:00","2019-09-30T00:00:00","2019-10-31T00:00:00","2019-11-30T00:00:00","2019-12-31T00:00:00","2020-01-31T00:00:00","2020-02-29T00:00:00","2020-03-31T00:00:00","2020-04-30T00:00:00","2020-05-31T00:00:00","2020-06-30T00:00:00","2020-07-31T00:00:00","2020-08-31T00:00:00","2020-09-30T00:00:00","2020-10-31T00:00:00","2020-11-30T00:00:00","2020-12-31T00:00:00","2021-01-31T00:00:00","2021-02-28T00:00:00","2021-03-31T00:00:00","2021-04-30T00:00:00","2021-05-31T00:00:00","2021-06-30T00:00:00","2021-07-31T00:00:00","2021-08-31T00:00:00","2021-09-30T00:00:00","2021-10-31T00:00:00","2021-11-30T00:00:00","2021-12-31T00:00:00","2022-01-31T00:00:00","2022-02-28T00:00:00","2022-03-31T00:00:00","2022-04-30T00:00:00","2022-05-31T00:00:00","2022-06-30T00:00:00","2022-07-31T00:00:00","2022-08-31T00:00:00","2022-09-30T00:00:00","2022-10-31T00:00:00","2022-11-30T00:00:00","2022-12-31T00:00:00","2023-01-31T00:00:00","2023-02-28T00:00:00","2023-03-31T00:00:00","2023-04-30T00:00:00","2023-05-31T00:00:00","2023-06-30T00:00:00","2023-07-31T00:00:00","2023-08-31T00:00:00","2023-09-30T00:00:00"],"xaxis":"x","y":[100.0,93.32782399744363,94.14287820949005,92.0550947734368,91.82271026666399,92.10359490907888,100.09965426257435,103.91674039815479,110.77863500204134,115.42062251398934,120.10211787821753,133.12029283741614,136.3362183309626,139.33763100831587,137.23822390620242,134.72593920311158,140.76117973226135,141.7678955992578,144.68718531632726,147.513212463 ...
